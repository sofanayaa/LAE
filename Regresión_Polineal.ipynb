# %% [markdown]
# Sofia Anaya Palafox
#
# 22 Enero 2026
#
# **Regresión Polineal**

# %%
import numpy as np
import pandas as pd

# %%
y=np.array([5,2,1,2,5])
X = np.array([[0, 0, 0], [1,1,1], [2,4,8], [3,9,27], [4,16,64]])

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X,y)
lr.intercept_
# Out:
# np.float64(4.999999999999989)

# %%
lr.coef_
# Out:
# array([-4.00000000e+00,  1.00000000e+00,  2.22044605e-16])
